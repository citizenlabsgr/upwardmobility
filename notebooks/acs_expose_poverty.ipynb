# %% [markdown]
# ### Merge ACS tract-level and place level data for diversity/poverty metrics

# %%
import os
if 'COLAB_GPU' in os.environ:
    from google.colab import  drive
    drive.mount('/drive')
    data_path = '/drive/Shared drives/Capstone/notebooks/data'
else:
    data_path = 'data'

# %%
import pandas as pd

us_tract = pd.read_csv(f'{data_path}/interim/us_tract_acs.csv')

# Calculate which tracts are high poverty - have poverty ratio below 1 for greater than 40% of residents
poverty_metric = 'poverty_ratio_below_1_people'

us_tract['high_poverty'] = us_tract['poverty_ratio_below_1_people'].apply(lambda x: 1 if x >.4 else 0)

# %% [markdown]
# ### Calculate Poverty Metric for all US Counties

# %%
# a bit less than 5% of tracts are considered high poverty under this metric
us_tract['high_poverty'].value_counts()
# for col in list(us_tract.columns):
#   print(col)

cols = ['all_in_poverty', 'population', 'poverty_ratio_below_1_people', 'high_poverty', 'population_county']
#us_tract[cols]

# %%
county_poverty = us_tract.groupby(['year','state','county', 'high_poverty']).sum()[['population','all_in_poverty']].unstack().reset_index()

county_poverty = county_poverty.fillna(0) # fill empty values with 0

county_poverty['proportion_high_poverty_neighborhood'] = county_poverty[('all_in_poverty',  1)]/(county_poverty[('all_in_poverty',  1)]+ county_poverty[('all_in_poverty',  0)])

county_poverty.columns = county_poverty.columns.droplevel(1)

county_poverty = county_poverty[['year','state','county', 'proportion_high_poverty_neighborhood']]


county_poverty.head()
# Out:
#    year  state  county  proportion_high_poverty_neighborhood
# 0  2019      1       1                              0.000000
# 1  2019      1       3                              0.000000
# 2  2019      1       5                              0.234909
# 3  2019      1       7                              0.000000
# 4  2019      1       9                              0.000000

# %% [markdown]
# ### Calculate diversity metric

# %%
column_mapper = {'population': 'population_county', 'hispanic_or_latino':'hispanic_or_latino_county', 'white':'white_county','black':'black_county', 'native_american': 'native_american_county', 'asian':'asian_county', 'hawaiian':'hawaiian_county', 'some_other_race_alone':'some_other_race_alone_county','two_more_races':'two_more_races_county'}

groupings = ['population', 'hispanic_or_latino', 'white','black', 'native_american', 'asian', 'hawaiian', 'some_other_race_alone','two_more_races']
county_race = us_tract.groupby(['state', 'county', 'year'])[groupings].sum().reset_index()
county_race = county_race.rename(columns = column_mapper)

us_tract = pd.merge(us_tract, county_race, on = ['state', 'county', 'year'], how = 'left')

# %%
races = ['hispanic_or_latino', 'white','black', 'native_american', 'asian', 'hawaiian', 'some_other_race_alone','two_more_races']


races_exposure = ['hispanic_or_latino_exposure', 'white_exposure','black_exposure', 'native_american_exposure', 'asian_exposure', 'hawaiian_exposure', 'some_other_race_alone_exposure','two_more_races_exposure']


for race in races:
  us_tract[race+'_exposure'] = (us_tract[race]*(us_tract['population']-us_tract[race]))/(us_tract[race + '_county']*us_tract['population'])


us_tract_exposure = us_tract.groupby(['state', 'county', 'year'])[races_exposure].sum().reset_index()

us_tract_exposure.head()
# Out:
#    state  county  year  hispanic_or_latino_exposure  white_exposure  \
# 0      1       1  2019                     0.956510        0.212265
# 1      1       3  2019                     0.922474        0.125351
# 2      1       5  2019                     0.920309        0.506731
# 3      1       7  2019                     0.962017        0.202068
# 4      1       9  2019                     0.846191        0.044934
#
#    black_exposure  native_american_exposure  asian_exposure  \
# 0        0.731823                  0.991504        0.972936
# 1        0.792728                  0.978007        0.971191
# 2        0.499511                  0.990500        0.989702
# 3        0.679886                  0.996733        0.997198
# 4        0.971955                  0.996659        0.994517
#
#    hawaiian_exposure  some_other_race_alone_exposure  two_more_races_exposure
# 0           0.991068                        0.955512                 0.965904
# 1           0.998263                        0.971838                 0.970935
# 2           0.999374                        0.927236                 0.982170
# 3           0.000000                        0.999066                 0.990628
# 4           0.993537                        0.973111                 0.978451

# %%
column_mapper = {'population': 'population_county', 'hispanic_or_latino':'hispanic_or_latino_county', 'white':'white_county','black':'black_county', 'native_american': 'native_american_county', 'asian':'asian_county', 'hawaiian':'hawaiian_county', 'some_other_race_alone':'some_other_race_alone_county','two_more_races':'two_more_races_county'}

groupings = ['population', 'hispanic_or_latino', 'white','black', 'native_american', 'asian', 'hawaiian', 'some_other_race_alone','two_more_races']

# %% [markdown]
# ### Merge diversity and poverty df and create csv file

# %%
df_diversity_poverty = pd.merge(us_tract_exposure, county_poverty, on= ['state', 'county', 'year'], how = 'inner')

df_diversity_poverty.head()
# Out:
#    state  county  year  hispanic_or_latino_exposure  white_exposure  \
# 0      1       1  2019                     0.956510        0.212265
# 1      1       3  2019                     0.922474        0.125351
# 2      1       5  2019                     0.920309        0.506731
# 3      1       7  2019                     0.962017        0.202068
# 4      1       9  2019                     0.846191        0.044934
#
#    black_exposure  native_american_exposure  asian_exposure  \
# 0        0.731823                  0.991504        0.972936
# 1        0.792728                  0.978007        0.971191
# 2        0.499511                  0.990500        0.989702
# 3        0.679886                  0.996733        0.997198
# 4        0.971955                  0.996659        0.994517
#
#    hawaiian_exposure  some_other_race_alone_exposure  two_more_races_exposure  \
# 0           0.991068                        0.955512                 0.965904
# 1           0.998263                        0.971838                 0.970935
# 2           0.999374                        0.927236                 0.982170
# 3           0.000000                        0.999066                 0.990628
# 4           0.993537                        0.973111                 0.978451
#
#    proportion_high_poverty_neighborhood
# 0                              0.000000
# 1                              0.000000
# 2                              0.234909
# 3                              0.000000
# 4                              0.000000

# %%
df_diversity_poverty.to_csv(f'{data_path}/interim/county_diversity_poverty.csv', index=False)

# %%
df_diversity_poverty.T
# Out:
#                                              0            1            2     \
# state                                    1.000000     1.000000     1.000000
# county                                   1.000000     3.000000     5.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.956510     0.922474     0.920309
# white_exposure                           0.212265     0.125351     0.506731
# black_exposure                           0.731823     0.792728     0.499511
# native_american_exposure                 0.991504     0.978007     0.990500
# asian_exposure                           0.972936     0.971191     0.989702
# hawaiian_exposure                        0.991068     0.998263     0.999374
# some_other_race_alone_exposure           0.955512     0.971838     0.927236
# two_more_races_exposure                  0.965904     0.970935     0.982170
# proportion_high_poverty_neighborhood     0.000000     0.000000     0.234909
#
#                                              3            4            5     \
# state                                    1.000000     1.000000     1.000000
# county                                   7.000000     9.000000    11.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.962017     0.846191     0.930308
# white_exposure                           0.202068     0.044934     0.695058
# black_exposure                           0.679886     0.971955     0.209959
# native_american_exposure                 0.996733     0.996659     0.000000
# asian_exposure                           0.997198     0.994517     0.991400
# hawaiian_exposure                        0.000000     0.993537     0.000000
# some_other_race_alone_exposure           0.999066     0.973111     0.929885
# two_more_races_exposure                  0.990628     0.978451     0.972680
# proportion_high_poverty_neighborhood     0.000000     0.000000     0.000000
#
#                                              6            7            8     \
# state                                    1.000000     1.000000     1.000000
# county                                  13.000000    15.000000    17.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.968031     0.885527     0.926053
# white_exposure                           0.408666     0.209271     0.393430
# black_exposure                           0.457972     0.610496     0.558683
# native_american_exposure                 0.996455     0.981954     0.993711
# asian_exposure                           0.982598     0.973751     0.972812
# hawaiian_exposure                        0.000000     0.995792     0.000000
# some_other_race_alone_exposure           0.988847     0.877792     0.987822
# two_more_races_exposure                  0.958986     0.958397     0.977436
# proportion_high_poverty_neighborhood     0.000000     0.102809     0.000000
#
#                                              9     ...         3209  \
# state                                    1.000000  ...    72.000000
# county                                  19.000000  ...   135.000000
# year                                  2019.000000  ...  2019.000000
# hispanic_or_latino_exposure              0.978155  ...     0.013605
# white_exposure                           0.070044  ...     0.171079
# black_exposure                           0.928365  ...     0.920172
# native_american_exposure                 0.970712  ...     0.992736
# asian_exposure                           0.994112  ...     0.957535
# hawaiian_exposure                        0.000000  ...     0.998985
# some_other_race_alone_exposure           0.990375  ...     0.926423
# two_more_races_exposure                  0.981678  ...     0.945298
# proportion_high_poverty_neighborhood     0.000000  ...     0.461168
#
#                                              3210         3211         3212  \
# state                                   72.000000    72.000000    72.000000
# county                                 137.000000   139.000000   141.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.013104     0.008462     0.007589
# white_exposure                           0.264834     0.201365     0.465485
# black_exposure                           0.859052     0.879320     0.978400
# native_american_exposure                 0.997173     0.994380     0.995694
# asian_exposure                           0.000000     0.977863     0.993508
# hawaiian_exposure                        0.000000     0.000000     0.000000
# some_other_race_alone_exposure           0.862423     0.924400     0.554438
# two_more_races_exposure                  0.923512     0.937266     0.969131
# proportion_high_poverty_neighborhood     0.565417     0.325572     1.000000
#
#                                              3213         3214         3215  \
# state                                   72.000000    72.000000    72.000000
# county                                 143.000000   145.000000   147.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.015619     0.032445     0.050671
# white_exposure                           0.283495     0.166501     0.449506
# black_exposure                           0.887603     0.938839     0.909083
# native_american_exposure                 0.000000     0.990132     0.998196
# asian_exposure                           0.990677     0.998045     0.996843
# hawaiian_exposure                        0.000000     0.999222     0.000000
# some_other_race_alone_exposure           0.839573     0.877698     0.624326
# two_more_races_exposure                  0.972967     0.983145     0.980153
# proportion_high_poverty_neighborhood     0.685527     0.744742     0.669369
#
#                                              3216         3217         3218
# state                                   72.000000    72.000000    72.000000
# county                                 149.000000   151.000000   153.000000
# year                                  2019.000000  2019.000000  2019.000000
# hispanic_or_latino_exposure              0.002538     0.000804     0.006318
# white_exposure                           0.416639     0.799070     0.245679
# black_exposure                           0.950977     0.207681     0.945775
# native_american_exposure                 0.000000     0.000000     0.988427
# asian_exposure                           0.000000     0.995240     0.997178
# hawaiian_exposure                        0.000000     0.000000     0.000000
# some_other_race_alone_exposure           0.865965     0.974065     0.791164
# two_more_races_exposure                  0.704366     0.987244     0.987710
# proportion_high_poverty_neighborhood     0.845127     1.000000     0.744457
#
# [12 rows x 3219 columns]
